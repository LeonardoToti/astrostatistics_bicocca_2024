# %%
import numpy as np
import scipy.stats
import pylab as plt
import random

#function the exponential

# %%
N = 100

mu = 0
sigma = 3

xi = scipy.stats.halfnorm.rvs(mu, sigma, N)

#print(xi)
def fun(x):
    return x**3



#print(integral)
print(2*sigma**4)
# Out:
# 162

# %%
integral = []
difference = []

h = 0

for N in range (100, 10000, 100):
    xi = scipy.stats.halfnorm.rvs(mu, sigma, N)
    integral.append(np.sqrt(np.pi/2)*sigma * np.mean(fun(xi)))
    difference.append(np.abs(integral[h] - (2*sigma**4)))
    h = h + 1

# %%
plt.plot(difference)

# %%
#Same value of N but many times
from tqdm import tqdm
mu = 0
sigma = 3 

integral_2 = []
difference_2 = []

N = 10000
M = 10000
for h in tqdm(range (M)):
    xi = scipy.stats.halfnorm.rvs(mu, sigma, N)
    integral_2.append(np.sqrt(np.pi/2)*sigma * np.mean(fun(xi)))
    difference_2.append(np.abs(integral_2[h] - (2*sigma**4)))
# Out:
# 100%|██████████| 10000/10000 [00:08<00:00, 1144.33it/s]

# %%
bins = int(np.round(np.sqrt(10000)))
Counts,Bins,_ = plt.hist( integral_2, bins)
plt.hist( integral_2, bins)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from scipy.stats import norm

bins = int(np.round(np.sqrt(10000)))
Counts,Bins,_ = plt.hist( integral_2, bins, density=True, color='green')

mu, std = norm.fit(integral_2)
print(mu)
print(std)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2)

plt.show
# Out:
# 162.00274255906365
# 3.5534833356236506
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#N basso
#Same value of N but many times
from tqdm import tqdm

mu = 0
sigma = 3

integral_3 = []
difference_3 = []

N = 10
M = 10000
for h in tqdm(range (M)):
    xi = scipy.stats.halfnorm.rvs(mu, sigma, N)
    integral_3.append(np.sqrt(np.pi/2)*sigma * np.mean(fun(xi)))
    difference_3.append(np.abs(integral_3[h] - (2*sigma**4)))
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 11065.12it/s]

# %%
from scipy.stats import norm

bins = int(np.round(np.sqrt(10000)))
Counts,Bins,_ = plt.hist( integral_3, bins, density=True, color='green')

mu, std = norm.fit(integral_3)
print(mu)
print(std)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'r', linewidth=2)

plt.show
# Out:
# 160.71377291906353
# 113.9632497408881
# <function matplotlib.pyplot.show(close=None, block=None)>
